# %%
HF_KEY = 'hsdfsddsfgdsf'  # replace with your own token: huggingface.co/settings/tokens
GROQ_API_KEY = 'gsk_dfjdkfng'

# %% [markdown]
# # Groq to use Llama3

# %%
from groq import Groq

client = Groq(
    api_key= GROQ_API_KEY
)

chat_completion = client.chat.completions.create(
    messages=[
        {
            "role": "user",
            "content":  "What is the capital of France?"
        }
    ],
    model="llama-3.3-70b-versatile",
)

print(chat_completion.choices[0].message.content)
# Out:
# The capital of France is Paris.

# %% [markdown]
# # Using Inference with [Together AI](https://together.ai/) to use DeepSeek R1

# %%
import huggingface_hub; huggingface_hub.__version__
# Out:
# '0.33.2'

# %%
from huggingface_hub import InferenceClient

client = InferenceClient(
	provider="together",
	api_key=HF_KEY
)

messages = [
	{
		"role": "user",
		"content": "What is the capital of France?"
	}
]

completion = client.chat.completions.create(
    model="deepseek-ai/DeepSeek-R1", 
	messages=messages, 
	max_tokens=1024,
)

# %%
print(completion.choices[0].message.content)
# Out:
# <think>
# Okay, the user is asking about the capital of France. That's a straightforward geography question.
#
# Hmm, I recall that Paris is one of the most famous capitals in the world, so this should be easy. But let me double-check mentally - yes, definitely Paris.
#
# The user might be a student doing homework, a traveler planning a trip, or just someone confirming basic knowledge. Since they didn't provide context, I'll keep it simple.
#
# I should add that it's located along the Seine River - that's a nice geographical detail that makes the answer more informative without being overwhelming.
#
# The Eiffel Tower mention serves as both a recognizable landmark and a subtle prompt for potential follow-up questions about tourism.
#
# Keeping it concise but adding that one extra fact strikes a good balance between being helpful and not over-answering a simple question.
# </think>
# The capital of France is **Paris**.
#
# Here are a few key details about Paris:
# - Located in the north-central part of France, along the Seine River.
# - Serves as the country's political, economic, and cultural center.
# - Famous for landmarks like the **Eiffel Tower**, **Louvre Museum**, **Notre-Dame Cathedral**, and the **Champs-Élysées**.
# - Hosted the 2024 Summer Olympics.
#
# Let me know if you'd like more information! 🇫🇷

# %%
from huggingface_hub import InferenceClient

client = InferenceClient(
	# provider="together",  without together will choose any provider or might error if none are available
	api_key=HF_KEY
)
completion = client.chat.completions.create(
    model="deepseek-ai/DeepSeek-R1", 
	messages=messages, 
	max_tokens=1024,
)

# %%
print(completion.choices[0].message.content)
# Out:
# <think>
# Okay, the user is asking about the capital of France. That's a straightforward geography question.
#
# Hmm, I recall that Paris is one of the most famous capitals in the world, so this should be easy. But let me double-check mentally - yes, definitely Paris.
#
# The user might be a student doing homework, a traveler planning a trip, or just someone confirming basic knowledge. Since they didn't provide context, I'll keep it simple.
#
# I should add that it's located along the Seine River - that's a nice geographical detail that makes the answer more informative without being overwhelming.
#
# The Eiffel Tower mention serves as both a recognizable landmark and a subtle confirmation that we're talking about the right Paris.
#
# No need to overcomplicate this - clear, concise, and accurate is best here. The smiley face at the end keeps it friendly for such a basic question.
# </think>
# The capital of France is **Paris**.
#
# Paris is located in the north-central part of the country, along the Seine River. It is renowned for its art, culture, history, and iconic landmarks like the **Eiffel Tower**, the Louvre Museum, and Notre-Dame Cathedral. 🇫🇷
